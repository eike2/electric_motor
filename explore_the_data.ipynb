# %%
## explore the data
# Task 1 & 2
# import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Render plots inline
# %matplotlib inline

# Make the graphs a bit prettier, and bigger
plt.rcParams['figure.figsize'] = (15, 5)

# import test data
df = pd.read_csv('trainingset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842030 entries, 0 to 842029
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   u_q             842030 non-null  float64
#  1   coolant         842030 non-null  float64
#  2   stator_winding  842030 non-null  float64
#  3   u_d             842030 non-null  float64
#  4   stator_tooth    842030 non-null  float64
#  5   motor_speed     842030 non-null  float64
#  6   i_d             842030 non-null  float64
#  7   i_q             842030 non-null  float64
#  8   pm              842030 non-null  float64
#  9   stator_yoke     842030 non-null  float64
#  10  ambient         842030 non-null  float64
#  11  torque          842030 non-null  float64
#  12  profile_id      842030 non-null  int64
# dtypes: float64(12), int64(1)
# memory usage: 83.5 MB

# %%
# Task 3
df.describe()
# Out:
#                  u_q        coolant  stator_winding            u_d  \
# count  842030.000000  842030.000000   842030.000000  842030.000000
# mean       56.069275      35.639635       69.901781     -31.708372
# std        44.918425      21.342347       29.197320      64.306048
# min       -17.991308      10.623751       19.049341    -131.288696
# 25%        13.689408      18.727773       45.986175     -88.555258
# 50%        47.717177      24.904963       67.180672     -11.629204
# 75%        93.896770      49.811091       92.601009       0.387280
# max       133.036994     101.598512      141.362885     131.108254
#
#         stator_tooth    motor_speed            i_d            i_q  \
# count  842030.000000  842030.000000  842030.000000  842030.000000
# mean       59.187436    2396.014003     -78.165820      46.124004
# std        22.793751    1872.717242      66.940817      93.545990
# min        18.271248    -275.549144    -269.230377    -293.426793
# 25%        42.759530     564.963363    -122.971221       1.096272
# 50%        58.361753    2249.991699     -67.842434      38.778025
# 75%        78.706665    3999.956543     -13.556941     111.414449
# max       111.423227    5999.966797       0.051897     301.707855
#
#                   pm    stator_yoke        ambient         torque  \
# count  842030.000000  842030.000000  842030.000000   8.420300e+05
# mean       60.450425      49.375362      24.492827   3.879078e+01
# std        19.456823      19.442457       2.076355   7.856033e+01
# min        20.856956      18.270548       8.783478  -2.464667e+02
# 25%        45.323203      34.662624      23.155986 -3.316361e-181
# 50%        62.138350      47.105015      24.746414   3.207300e+01
# 75%        74.067494      60.963856      26.314739   9.552463e+01
# max       113.606628     101.147964      30.714205   2.610057e+02
#
#           profile_id
# count  842030.000000
# mean       39.588174
# std        17.913370
# min        13.000000
# 25%        21.000000
# 50%        42.000000
# 75%        56.000000
# max        66.000000

# %%
# Task 4
# traget attribute: pm

# Task 5
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Task 6
corr = df.corr()
corr
# Out:
#                      u_q   coolant  stator_winding       u_d  stator_tooth  \
# u_q             1.000000  0.119732        0.002283  0.082203      0.093537
# coolant         0.119732  1.000000        0.418444  0.227052      0.612386
# stator_winding  0.002283  0.418444        1.000000 -0.298686      0.965927
# u_d             0.082203  0.227052       -0.298686  1.000000     -0.191251
# stator_tooth    0.093537  0.612386        0.965927 -0.191251      1.000000
# motor_speed     0.631269 -0.018249        0.433028 -0.303158      0.411001
# i_d             0.013901  0.151891       -0.654831  0.514455     -0.506004
# i_q            -0.199047 -0.262858        0.097268 -0.691939     -0.025255
# pm              0.137910  0.391039        0.789100 -0.220307      0.828134
# stator_yoke     0.116354  0.834186        0.835821 -0.025754      0.943326
# ambient         0.191859  0.572925        0.307474  0.239005      0.440002
# torque         -0.215066 -0.271566        0.131854 -0.727992      0.001346
# profile_id      0.066212  0.622697        0.250168  0.292379      0.380530
#
#                 motor_speed       i_d       i_q        pm  stator_yoke  \
# u_q                0.631269  0.013901 -0.199047  0.137910     0.116354
# coolant           -0.018249  0.151891 -0.262858  0.391039     0.834186
# stator_winding     0.433028 -0.654831  0.097268  0.789100     0.835821
# u_d               -0.303158  0.514455 -0.691939 -0.220307    -0.025754
# stator_tooth       0.411001 -0.506004 -0.025255  0.828134     0.943326
# motor_speed        1.000000 -0.665947 -0.115927  0.508834     0.255888
# i_d               -0.665947  1.000000 -0.252984 -0.459680    -0.262879
# i_q               -0.115927 -0.252984  1.000000 -0.137655    -0.126102
# pm                 0.508834 -0.459680 -0.137655  1.000000     0.733996
# stator_yoke        0.255888 -0.262879 -0.126102  0.733996     1.000000
# ambient            0.100396  0.059355 -0.311511  0.464106     0.547164
# torque            -0.085526 -0.305287  0.995963 -0.108994    -0.112849
# profile_id        -0.047590  0.134796 -0.341328  0.293499     0.521372
#
#                  ambient    torque  profile_id
# u_q             0.191859 -0.215066    0.066212
# coolant         0.572925 -0.271566    0.622697
# stator_winding  0.307474  0.131854    0.250168
# u_d             0.239005 -0.727992    0.292379
# stator_tooth    0.440002  0.001346    0.380530
# motor_speed     0.100396 -0.085526   -0.047590
# i_d             0.059355 -0.305287    0.134796
# i_q            -0.311511  0.995963   -0.341328
# pm              0.464106 -0.108994    0.293499
# stator_yoke     0.547164 -0.112849    0.521372
# ambient         1.000000 -0.318815    0.597060
# torque         -0.318815  1.000000   -0.345627
# profile_id      0.597060 -0.345627    1.000000

# %%
# heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# Task 7 & 8 ?
